# %%
import sys
import torch
import numpy as np
from matplotlib import pyplot as plt
import json
from itertools import product
sys.path.append('/home/wilson/Finite-groups/src')
from model import MLP3
from evals import load_model
from utils import dotdict
from group_data import *
# %load_ext autoreload
# %autoreload 2

# %%
params = dotdict(dict(
    group_string='Z(100);Z(50,2)',
    delta_frac=0.,
    intersect_frac=1.,
    train_frac=1.,
))

# %%
gd = GroupData(params)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 m = MLP3(5, params)
#
# File ~/Finite-groups/src/model.py:80, in MLP3.__init__(self, N, params)
#      75 self.params = params
#      76 self.N = N
#      78 self.embedding_left = custom_kaiming(
#      79     [
# ---> 80         params.instances,
#      81         self.N,
#      82         params.embed_dim,
#      83     ]
#      84 )
#      86 self.embedding_right = custom_kaiming(
#      87     [params.instances, self.N, params.embed_dim]
#      88 )
#      90 self.linear = custom_kaiming(
#      91     [params.instances, params.embed_dim, params.hidden_size]
#      92 )
#
# KeyError: 'instances'

# %%
gd.frequency_histogram()
plt.show()

# %%
prefix = '/workspace/Finite-groups/src/models'
#path = f'{prefix}/2024_07_21_21_21_51_Z_50__clamped_50_'
#path = f'{prefix}/2024_07_21_22_38_07_Z_100__Z_2_50_'
path = f'{prefix}/2024_07_21_22_48_54_Z_48_2__twZ_48_'

# %%
fig = load_model(path, 0)
# Out:
# Intersection size: 6912/9216 (0.75)
# Added 6912 elements from intersection
# Added 0 elements from group 0: Z(48,2)
# Added 0 elements from group 1: twZ(48)
# Taking random subset: 6912/6912 (1.00)
# Train set size: 6912

# %%
fig.show()

# %%
loss_dict = torch.load('/workspace/Finite-groups/src/models/2024-07-13_00-37-04_long_run/losses/007940.pt')
loss_dict = {k: v.detach().cpu().numpy() for k, v in loss_dict.items()}

# %%
loss_dict.keys()
# Out:
# dict_keys(['G1_loss', 'G2_loss', 'G1_accuracy', 'G2_accuracy', 'epoch_train_loss', 'epoch_train_acc', 'epoch_train_margin'])

# %%
plt.scatter(loss_dict['G1_loss'], loss_dict['epoch_train_loss'])
plt.show()

# %%
path = '/home/wilson/Finite-groups/src/models/2024-07-13_19-30-43_four'

# %%
params = json.load(open(f'{path}/params.json', 'r'))

# %%
params = dotdict(params)

# %%
test_inputs = torch.tensor(list(product(range(params.N), repeat=2)), device='cpu')

# %%
model = MLP3(params)
state = torch.load(f'{path}/ckpts/001998.pt')
model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
model.linear.shape
# Out:
# torch.Size([100, 2, 8])

# %%
logits = model(test_inputs)

# %%
loss = torch.load(f'{path}/losses/001998.pt')

# %%
good = (loss['epoch_train_acc'] == 1).nonzero()

# %%
for i in good.cpu().numpy().flatten():
    print(logits.max(dim=2).indices[:,i].reshape((4, 4)))#[1::2,1::2])
# Out:
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 2, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 0, 3, 2],
#         [2, 3, 0, 1],
#         [3, 1, 1, 0]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 0],
#         [2, 3, 0, 1],
#         [3, 0, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 0, 3, 1],
#         [2, 3, 0, 1],
#         [3, 0, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 0],
#         [2, 3, 0, 1],
#         [3, 1, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 2],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 0, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 0],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 0],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 2],
#         [2, 3, 0, 1],
#         [3, 2, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 0]])
# tensor([[0, 1, 2, 3],
#         [1, 0, 3, 3],
#         [2, 3, 0, 1],
#         [3, 0, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 2],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 0],
#         [2, 3, 0, 1],
#         [3, 0, 1, 0]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 3],
#         [2, 3, 0, 1],
#         [3, 0, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 0, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 2],
#         [2, 3, 0, 1],
#         [3, 0, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 2],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 0],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 0, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 0, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 2, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 0, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 2],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 0, 3, 0],
#         [2, 3, 0, 1],
#         [3, 1, 1, 0]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 2],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 3],
#         [2, 3, 0, 1],
#         [3, 0, 1, 1]])
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 0],
#         [2, 3, 0, 1],
#         [3, 2, 1, 2]])
# tensor([[0, 1, 2, 3],
#         [1, 1, 3, 1],
#         [2, 3, 0, 1],
#         [3, 3, 1, 0]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 1],
#         [2, 3, 0, 1],
#         [3, 1, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 3, 1, 3]])
# tensor([[0, 1, 2, 3],
#         [1, 3, 3, 3],
#         [2, 3, 0, 1],
#         [3, 1, 1, 2]])

# %%
test_inputs[0]
# Out:
# tensor([0, 0], device='cuda:0')

# %%
mult_table = np.zeros((96, 96))

# %%
instance = 0
for n, (i, j) in enumerate(test_inputs):
    i = i.item()
    j = j.item()
    mult_table[i, j] = logits[n, instance].item()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[53], line 5
#       3 i = i.item()
#       4 j = j.item()
# ----> 5 mult_table[i, j] = logits[n, instance].item()
#
# RuntimeError: a Tensor with 96 elements cannot be converted to Scalar
