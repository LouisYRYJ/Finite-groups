# %%
import sys
import torch as t
import numpy as np
from matplotlib import pyplot as plt
import json
from itertools import product
sys.path.append('/workspace/wilson/Finite-groups/src')
from model import MLP3, MLP4, InstancedModule
from utils import *
from group_data import *
from jaxtyping import Float
from typing import Union
from einops import repeat
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
import plotly.graph_objects as go
import copy
import math
from itertools import product
from llc import *
import gc

# %load_ext autoreload
# %autoreload 2

# %%
device = t.device("cuda" if t.cuda.is_available() else "cpu")

# %%
#path = '/workspace/models/2024_08_02_02_17_18_S_5_'
#path = '/workspace/models/2024_08_03_00_04_30_Z_48_2_'
# path = '/workspace/models/2024_08_04_00_13_28_Z_48_2__twZ_48_'
#path = '/workspace/models/2024_08_03_21_29_50_Z_48_2__MLP4_512'
path = '/workspace/models/2024_08_05_18_31_53_S_5__times_A_5__Z_2__'
models, params = load_models(path, sel=slice(400))
# Out:
# 100%|██████████| 400/400 [03:48<00:00,  1.75it/s]

# %%
dataset = GroupData(params)
# Out:
# Intersection size: 7920/14400 (0.55)
# Added 7920 elements from intersection
# Added 0 elements from group 0: S(5)
# Added 0 elements from group 1: times(A(5),Z(2))
# Train set size: 7920/14400 (0.55)

# %%
def llc_v_epoch(model_traj, dataset, instance, sgld_epochs=2000, eps=3e-3, beta=1e3, gamma=1., chains=1, cbatch_size=1, behavioral=True):
    gc.collect()
    t.cuda.empty_cache()
    llc, trace = get_llc(
        model_traj, dataset, eps=eps, beta=beta, gamma=gamma, chains=chains, cbatch_size=cbatch_size, behavioral=behavioral, epochs=sgld_epochs
    )
    loss_dict = test_loss(model_traj, dataset)
    return llc.tolist(), {k: v.detach().cpu().tolist() for k, v in loss_dict.items()}

# %%
def plot_llc_v_epoch(llc, loss_dict, instance):
    fig, ax = plt.subplots()
    ax.plot(llc, label='llc')
    ax.legend()
    ax2 = ax.twinx()
    ax2.plot(loss_dict['G0_acc'], label='G0_acc', c='r', alpha=0.5)
    ax2.plot(loss_dict['G1_acc'], label='G1_acc', c='g', alpha=0.5)
    plt.title(f'S5 v A(5)xZ(2) instance {instance:03}')
    plt.legend()
    plt.show()

# %%
gc.collect()
t.cuda.empty_cache()

# %%
inst = 5
model_traj = MLP3.stack([model[inst] for model in models[:400]]).to(device)
gc.collect()
t.cuda.empty_cache()
llc, loss_dict = llc_v_epoch(model_traj, dataset, inst, sgld_epochs=2000, chains=3, eps=8e-4, cbatch_size=1)
plot_llc_v_epoch(llc, loss_dict, inst)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[12], line 5
#       3 gc.collect()
#       4 t.cuda.empty_cache()
# ----> 5 llc, loss_dict = llc_v_epoch(model_traj, dataset, inst, sgld_epochs=2000, chains=3, eps=8e-4, cbatch_size=1)
#       6 plot_llc_v_epoch(llc, loss_dict, inst)
#
# Cell In[9], line 4, in llc_v_epoch(model_traj, dataset, instance, sgld_epochs, eps, beta, gamma, chains, cbatch_size, behavioral)
#       2 gc.collect()
#       3 t.cuda.empty_cache()
# ----> 4 llc, trace = get_llc(
#       5     model_traj, dataset, eps=eps, beta=beta, gamma=gamma, chains=chains, cbatch_size=cbatch_size, behavioral=behavioral, epochs=sgld_epochs
#       6 )
#       7 loss_dict = test_loss(model_traj, dataset)
#       8 return llc.tolist(), {k: v.detach().cpu().tolist() for k, v in loss_dict.items()}
#
# ...

# %%
del model_traj
gc.collect()
t.cuda.empty_cache()

# %%
inst = 55
model_traj = MLP3.stack([model[inst] for model in models[:400]]).to(device)
gc.collect()
t.cuda.empty_cache()
llc, loss_dict = llc_v_epoch(model_traj, dataset, inst, sgld_epochs=2000, chains=3, eps=8e-4, cbatch_size=1)
plot_llc_v_epoch(llc, loss_dict, inst)
# Out:
# ...
# SGLD:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
inst = 97
model_traj = MLP3.stack([model[inst] for model in models[:400]]).to(device)
gc.collect()
t.cuda.empty_cache()
llc, loss_dict = llc_v_epoch(model_traj, dataset, inst, sgld_epochs=2000, chains=3, eps=8e-4, cbatch_size=1)
plot_llc_v_epoch(llc, loss_dict, inst)
# Out:
# ...
# SGLD:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
llc, loss_dict = llc_v_epoch(models, dataset, 0)
# Out:
# SGLD:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
llc, loss_dict = plot_llc_epochs(models, dataset, 97)
# Out:
# SGLD:   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 llc, loss_dict = plot_llc_epochs(models, dataset, 97)
#
# Cell In[51], line 5, in plot_llc_epochs(models, dataset, instance, train_epochs, sgld_epochs, eps, beta, gamma, chains, cbatch_size, behavioral)
#       3 t.cuda.empty_cache()
#       4 model_traj = MLP3.stack([model[0] for model in models[:train_epochs]]).to(device)
# ----> 5 llc = get_llc(
#       6     model_traj, dataset, eps=eps, beta=beta, gamma=gamma, chains=chains, cbatch_size=cbatch_size, behavioral=behavioral, epochs=sgld_epochs
#       7 )
#       8 loss_dict = test_loss(model_traj, dataset)
#       9 fig, ax = plt.subplots()
#
# ...

# %%
f'{5:02}'
# Out:
# '05'

# %%
# Out:
# SGLD:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
#del model_traj
import gc
gc.collect()
t.cuda.empty_cache()
model_traj = MLP3.stack([model[55] for model in models[:]])
model_traj = model_traj[:400].to(device)
bllc = get_llc(
    model_traj, dataset, eps=3e-3, beta=1e3, gamma=1., chains=1, cbatch_size=1, replacement=False, behavioral=True, epochs=2000, burnin=0.8
)
loss_dict = test_loss(model_traj, dataset)
# Out:
# SGLD:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
plt.plot(bllc.tolist(), label='llc')
plt.plot((loss_dict['G0_acc'].detach().cpu().numpy() * 5000).tolist(), label='G0_acc')
plt.plot((loss_dict['G1_acc'].detach().cpu().numpy() * 5000).tolist(), label='G1_acc')
plt.title('S5 v A(5)xZ(2) instance 055')
plt.legend()
plt.show()
